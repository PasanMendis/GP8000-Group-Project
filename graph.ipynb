# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("train.csv")

# %%
# Make sure Gross is numeric
df["Gross"] = pd.to_numeric(df["Gross"], errors="coerce")
df = df.dropna(subset=["Gross"])

# --- Histogram (raw values) ---
plt.figure(figsize=(8,5))
plt.hist(df["Gross"], bins=50, color="skyblue", edgecolor="black")
plt.xlabel("Gross ($)")
plt.ylabel("Count")
plt.title("Distribution of Gross (train.csv)")
plt.tight_layout()
plt.show()

# --- Summary statistics ---
print(df["Gross"].describe(percentiles=[0.25,0.5,0.75,0.9,0.95,0.99]))
# Out:
# count    3.950000e+02
# mean     8.870385e+07
# std      1.176449e+08
# min      3.600000e+03
# 25%      1.198224e+07
# 50%      4.587517e+07
# 75%      1.200301e+08
# 90%      2.333417e+08
# 95%      2.977761e+08
# 99%      6.116264e+08
# max      8.583730e+08
# Name: Gross, dtype: float64

# %%
df["Gross"].sort_values(ascending=True)
# Out:
# 19          3600.0
# 226         7461.0
# 238        10177.0
# 392        12562.0
# 124        70147.0
#           ...
# 196    608581744.0
# 359    659325379.0
# 333    678815482.0
# 178    760507625.0
# 301    858373000.0
# Name: Gross, Length: 395, dtype: float64
